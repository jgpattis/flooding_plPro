# %%
import mdtraj as md
import pyemma.coordinates as coor
import numpy as np
import matplotlib.pyplot as plt
import pyemma.plots as pyemma_plots

# %%
yrl_10_gro = md.load('7OFS/10_milli_molar/analysis/frame0_nw.gro')
yrl_10 = md.load('7OFS/10_milli_molar/analysis/plpro_yrl_10_whole_wrap.trr', top=yrl_10_gro.top)

yrl_50_gro = md.load('7OFS/50_milli_molar/analysis/frame0_nw.gro')
yrl_50 = md.load('7OFS/50_milli_molar/analysis/plpro_yrl_50_whole_wrap.trr', top= yrl_50_gro.top)

yrl_100_gro = md.load('7OFS/100_milli_molar/analysis/frame0_nw.gro')
yrl_100 = md.load('7OFS/100_milli_molar/analysis/plpro_yrl_100_whole_wrap.trr', top=yrl_100_gro.top)

# %%
hba_10_gro = md.load('7oft/10_mm/analysis/frame0_nw.gro')
hba_10 = md.load('7oft/10_mm/analysis/7oft_10mm_whole_wrap.trr', top=hba_10_gro.top)

hba_50_gro = md.load('7oft/50_mm/analysis/frame0_nw.gro')
hba_50 = md.load('7oft/50_mm/analysis/7oft_50mm_whole_wrap.trr', top=hba_50_gro.top)

hba_100_gro = md.load('7oft/100_mm/analysis/frame0_nw.gro')
hba_100 = md.load('7oft/100_mm/analysis/7oft_100mm_whole_wrap.trr', top=hba_100_gro.top)

# %%
he9_10_gro = md.load('7ofu/10_mm/analysis/frame0_nw.gro')
he9_10 = md.load('7ofu/10_mm/analysis/7ofu_10mm_whole_wrap.trr', top=he9_10_gro.top)

he9_50_gro = md.load('7ofu/50_mm/analysis/frame0_nw.gro')
he9_50 = md.load('7ofu/50_mm/analysis/7ofu_50mm_whole_wrap.trr', top=he9_50_gro.top)

he9_100_gro = md.load('7ofu/100_mm/analysis/frame0_nw.gro')
he9_100 = md.load('7ofu/100_mm/analysis/7ofu_100mm_whole_wrap.trr', top=he9_100_gro.top)

# %%
time = np.arange(0,300.02, 0.01)

# %%
rms_yrl_10 = md.rmsd(yrl_10, yrl_10_gro, atom_indices=yrl_10_gro.top.select('backbone'))
rms_yrl_50 = md.rmsd(yrl_50, yrl_50_gro, atom_indices=yrl_10_gro.top.select('backbone'))
rms_yrl_100 = md.rmsd(yrl_100, yrl_100_gro, atom_indices=yrl_10_gro.top.select('backbone'))

rms_hba_10 = md.rmsd(hba_10, hba_10_gro, atom_indices=hba_10_gro.top.select('backbone'))
rms_hba_50 = md.rmsd(hba_50, hba_50_gro, atom_indices=hba_10_gro.top.select('backbone'))
rms_hba_100 = md.rmsd(hba_100, hba_100_gro, atom_indices=hba_10_gro.top.select('backbone'))

rms_he9_10 = md.rmsd(he9_10, he9_10_gro, atom_indices=he9_10_gro.top.select('backbone'))
rms_he9_50 = md.rmsd(he9_50, he9_50_gro, atom_indices=he9_10_gro.top.select('backbone'))
rms_he9_100 = md.rmsd(he9_100, he9_100_gro, atom_indices=he9_10_gro.top.select('backbone'))
# Out:
# /tmp/ipykernel_9701/13241585.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rms_yrl_10 = md.rmsd(yrl_10, yrl_10_gro, atom_indices=yrl_10_gro.top.select('backbone'))
# ...

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
ax[0][0].plot(time, rms_yrl_10 *10, label='yrl 10 mm')
ax[0][1].plot(time, rms_yrl_50 *10, label='yrl 50 mm')
ax[0][2].plot(time, rms_yrl_100*10, label='yrl 100 mm')

ax[1][0].plot(time, rms_hba_10 *10, label='hba 10 mm')
ax[1][1].plot(time, rms_hba_50 *10, label='hba 50 mm')
ax[1][2].plot(time, rms_hba_100 *10, label='hba 100 mm')

ax[2][0].plot(time, rms_he9_10 *10, label='he9 10 mm')
ax[2][1].plot(time, rms_he9_50 *10, label='he9 50 mm')
ax[2][2].plot(time, rms_he9_100 *10, label='he9 100 mm')

ax[2][0].set_xlabel('time (ns)', fontsize=16)
ax[2][1].set_xlabel('time (ns)', fontsize=16)
ax[2][2].set_xlabel('time (ns)', fontsize=16)

ax[0][0].set_ylabel(r'RMSD ($\AA$)', fontsize=16)
ax[1][0].set_ylabel(r'RMSD ($\AA$)', fontsize=16)
ax[2][0].set_ylabel(r'RMSD ($\AA$)', fontsize=16)

ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
fig.savefig('rmsd_all9.png')

# %%
rmsf_yrl_10 = np.loadtxt('7OFS/10_milli_molar/analysis/rmsf.xvg', comments=['#','@'])
rmsf_yrl_50 = np.loadtxt('7OFS/50_milli_molar/analysis/rmsf.xvg', comments=['#','@'])
rmsf_yrl_100 = np.loadtxt('7OFS/100_milli_molar/analysis/rmsf.xvg', comments=['#','@'])

rmsf_hba_10 = np.loadtxt('7oft/10_mm/analysis/rmsf.xvg', comments=['#','@'])
rmsf_hba_50 = np.loadtxt('7oft/50_mm/analysis/rmsf.xvg', comments=['#','@'])
rmsf_hba_100 = np.loadtxt('7oft/100_mm/analysis/rmsf.xvg', comments=['#','@'])

rmsf_he9_10 = np.loadtxt('7ofu/10_mm/analysis/rmsf.xvg', comments=['#','@'])
rmsf_he9_50 = np.loadtxt('7ofu/50_mm/analysis/rmsf.xvg', comments=['#','@'])
rmsf_he9_100 = np.loadtxt('7ofu/100_mm/analysis/rmsf.xvg', comments=['#','@'])

# %%
res = np.arange(1,len(rmsf_yrl_10) + 1)

# %%
fig2, ax2 = plt.subplots(1,3, sharex=True, sharey=True, figsize=[19.2, 4.8])
ax2[0].plot(res, rmsf_yrl_10[:,1]*10, label='10 mm')
ax2[0].plot(res, rmsf_yrl_50[:,1]*10, label='50 mm')
ax2[0].plot(res, rmsf_yrl_100[:,1]*10, label='100 mm')

ax2[1].plot(res, rmsf_hba_10[:,1]*10, label='10 mm')
ax2[1].plot(res, rmsf_hba_50[:,1]*10, label='50 mm')
ax2[1].plot(res, rmsf_hba_100[:,1]*10, label='100 mm')

ax2[2].plot(res, rmsf_he9_10[:,1]*10, label='10 mm')
ax2[2].plot(res, rmsf_he9_50[:,1]*10, label='50 mm')
ax2[2].plot(res, rmsf_he9_100[:,1]*10, label='100 mm')
ax2[2].legend(fontsize=16)

ax2[0].set_ylabel(r'RMSF ($\AA$)', fontsize=16)
ax2[0].set_xlabel('Residue', fontsize=16)
ax2[1].set_xlabel('Residue', fontsize=16)
ax2[2].set_xlabel('Residue', fontsize=16)

ax2[0].set_title('yrl', fontsize=20)
ax2[1].set_title('hba', fontsize=20)
ax2[2].set_title('he9', fontsize=20)
fig2.savefig('rmsf_all9.png')

# %%
yrl_10_gro_cc = coor.featurizer('7OFS/10_milli_molar/analysis/frame0_nw.gro')
yrl_10_gro_cc.add_selection(yrl_10_gro_cc.select('backbone'), reference=yrl_10_gro, atom_indices=yrl_10_gro_cc.select('backbone'), ref_atom_indices=yrl_10_gro_cc.select('backbone'))
yrl_10_cc =coor.load('7OFS/10_milli_molar/analysis/plpro_yrl_10_whole_wrap.trr', features=yrl_10_gro_cc)

yrl_50_gro_cc = coor.featurizer('7OFS/50_milli_molar/analysis/frame0_nw.gro')
yrl_50_gro_cc.add_selection(yrl_50_gro_cc.select('backbone'), reference=yrl_10_gro, atom_indices=yrl_50_gro_cc.select('backbone'), ref_atom_indices=yrl_10_gro_cc.select('backbone'))
yrl_50_cc = coor.load('7OFS/50_milli_molar/analysis/plpro_yrl_50_whole_wrap.trr', features=yrl_50_gro_cc)

yrl_100_gro_cc = coor.featurizer('7OFS/100_milli_molar/analysis/frame0_nw.gro')
yrl_100_gro_cc.add_selection(yrl_100_gro_cc.select('backbone'), reference=yrl_10_gro, atom_indices=yrl_50_gro_cc.select('backbone'), ref_atom_indices=yrl_10_gro_cc.select('backbone'))
yrl_100_cc = coor.load('7OFS/100_milli_molar/analysis/plpro_yrl_100_whole_wrap.trr', features=yrl_100_gro_cc)

# %%
hba_10_gro_cc = coor.featurizer('7oft/10_mm/analysis/frame0_nw.gro')
hba_10_gro_cc.add_selection(hba_10_gro_cc.select('backbone'), reference=yrl_10_gro, atom_indices=yrl_10_gro_cc.select('backbone'), ref_atom_indices=yrl_10_gro_cc.select('backbone'))
hba_10_cc =coor.load('7oft/10_mm/analysis/7oft_10mm_whole_wrap.trr', features=hba_10_gro_cc)

hba_50_gro_cc = coor.featurizer('7oft/50_mm/analysis/frame0_nw.gro')
hba_50_gro_cc.add_selection(hba_50_gro_cc.select('backbone'), reference=yrl_10_gro, atom_indices=yrl_10_gro_cc.select('backbone'), ref_atom_indices=yrl_10_gro_cc.select('backbone'))
hba_50_cc = coor.load('7oft/50_mm/analysis/7oft_50mm_whole_wrap.trr', features=hba_50_gro_cc)

hba_100_gro_cc = coor.featurizer('7oft/100_mm/analysis/frame0_nw.gro')
hba_100_gro_cc.add_selection(hba_100_gro_cc.select('backbone'), reference=yrl_10_gro, atom_indices=yrl_10_gro_cc.select('backbone'), ref_atom_indices=yrl_10_gro_cc.select('backbone'))
hba_100_cc = coor.load('7oft/100_mm/analysis/7oft_100mm_whole_wrap.trr', features=hba_100_gro_cc)

# %%
he9_10_gro_cc = coor.featurizer('7ofu/10_mm/analysis/frame0_nw.gro')
he9_10_gro_cc.add_selection(he9_10_gro_cc.select('backbone'), reference=yrl_10_gro, atom_indices=yrl_10_gro_cc.select('backbone'), ref_atom_indices=yrl_10_gro_cc.select('backbone'))
he9_10_cc =coor.load('7ofu/10_mm/analysis/7ofu_10mm_whole_wrap.trr', features=he9_10_gro_cc)

he9_50_gro_cc = coor.featurizer('7ofu/50_mm/analysis/frame0_nw.gro')
he9_50_gro_cc.add_selection(he9_50_gro_cc.select('backbone'), reference=yrl_10_gro, atom_indices=yrl_10_gro_cc.select('backbone'), ref_atom_indices=yrl_10_gro_cc.select('backbone'))
he9_50_cc = coor.load('7ofu/50_mm/analysis/7ofu_50mm_whole_wrap.trr', features=he9_50_gro_cc)

he9_100_gro_cc = coor.featurizer('7ofu/100_mm/analysis/frame0_nw.gro')
he9_100_gro_cc.add_selection(he9_100_gro_cc.select('backbone'), reference=yrl_10_gro, atom_indices=yrl_10_gro_cc.select('backbone'), ref_atom_indices=yrl_10_gro_cc.select('backbone'))
he9_100_cc = coor.load('7ofu/100_mm/analysis/7ofu_100mm_whole_wrap.trr', features=he9_100_gro_cc)

# %%
pca = coor.pca(data=[yrl_10_cc, yrl_50_cc, yrl_100_cc, hba_10_cc, hba_50_cc, hba_100_cc, he9_10_cc, he9_50_cc, he9_100_cc])
# Out:
# calc mean+cov:   0%|                                     | 0/18 [00:00<?, ?it/s]

# %%
pca_data = pca.get_output()
pca.write_to_hdf5('pca_data_all9_cc_try2.h5')
# Out:
# ...
# writing output:   0%|                                    | 0/18 [00:00<?, ?it/s]

# %%
pca.cumvar[:10]
# Out:
# array([0.34366134, 0.52655973, 0.59628874, 0.64044563, 0.67144704,
#        0.6992869 , 0.72159571, 0.74188067, 0.75887345, 0.77300672])

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    pyemma_plots.plot_density(pca_data[i][:,0], pca_data[i][:,1], logscale=True, ax=j)
    
ax[2][0].set_xlabel('PC 1', fontsize=16)
ax[2][1].set_xlabel('PC 1', fontsize=16)
ax[2][2].set_xlabel('PC 1', fontsize=16)

ax[0][0].set_ylabel('PC 2', fontsize=16)
ax[1][0].set_ylabel('PC 2', fontsize=16)
ax[2][0].set_ylabel('PC 2', fontsize=16)

ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    pyemma_plots.plot_density(pca_data[i][:,0], pca_data[i][:,2], logscale=True, ax=j)
    
ax[2][0].set_xlabel('PC 1', fontsize=16)
ax[2][1].set_xlabel('PC 1', fontsize=16)
ax[2][2].set_xlabel('PC 1', fontsize=16)

ax[0][0].set_ylabel('PC 3', fontsize=16)
ax[1][0].set_ylabel('PC 3', fontsize=16)
ax[2][0].set_ylabel('PC 3', fontsize=16)

ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
def print_corr(pca, feat, ic=0, num=20, save=False, outname=None):
  ''' helpful printing function for finding correlations between features and tICs
  .. math::
  \mathbf{Corr}(X_i - \mu_i, \mathbf{\theta}_j) = \frac{1}{\sigma_{X_i - \mu_i}}\sum_l \sigma_{(X_i - \mu_i)(X_l - \mu_l} \mathbf{U}_{li}
  INPUTs
  tica: a pyemma tica object
  feat: a pyemma featurizer object with a featurizer.describe() method
  ic: Independent component index to find correlations to
  num: number of top features to print
  save: save to file or just print. Boolean
  outname: name of output file
  OUTPUT
  Feature label
  correlation value from correlation matrix
  feature index
  '''
  top = np.argsort(np.absolute(pca.feature_PC_correlation[:,ic]))[::-1]
  out = [(feat.describe()[top[i]], pca.feature_PC_correlation[:,ic][top[i]], top[i]) for i in range(num)]
  if save==True:
    np.savetxt(f'{outname}.txt', out)
  print('Feature Label    Correlation   Feature index')
  for line in out: print(line)

# %%
print_corr(pca, yrl_10_gro_cc, ic=0)
# Out:
# Feature Label    Correlation   Feature index
# ('aligned ATOM:MET 23 C 377 y', 0.9781858788514477, 271)
# ('aligned ATOM:MET 23 CA 364 y', 0.9773527765370165, 268)
# ('aligned ATOM:MET 23 O 378 y', 0.9757804025007404, 274)
# ('aligned ATOM:PRO 46 N 712 y', 0.974276084161163, 541)
# ('aligned ATOM:THR 26 CA 409 y', 0.9734606767534643, 304)
# ('aligned ATOM:MET 25 O 406 y', 0.9718670258722857, 298)
# ('aligned ATOM:SER 24 N 379 y', 0.9714771446551034, 277)
# ('aligned ATOM:SER 24 CA 381 y', 0.9713689220467886, 280)
# ('aligned ATOM:PRO 46 CA 716 y', 0.9708767363428729, 544)
# ('aligned ATOM:SER 24 C 388 y', 0.9689949149846143, 283)
# ('aligned ATOM:SER 24 O 389 y', 0.9687583305379573, 286)
# ('aligned ATOM:THR 26 N 407 y', 0.9686209822048052, 301)
# ('aligned ATOM:MET 25 C 405 y', 0.9668115020069219, 295)
# ('aligned ATOM:LYS 45 CA 692 y', 0.96609245931721, 532)
# ('aligned ATOM:TYR 27 N 421 y', 0.9635595887920497, 313)
# ('aligned ATOM:MET 25 N 390 y', 0.9630835361111278, 289)
# ...

# %%
print_corr(pca, yrl_10_gro_cc, ic=1)
# Out:
# Feature Label    Correlation   Feature index
# ('aligned ATOM:THR 18 C 299 y', -0.942490604457353, 211)
# ('aligned ATOM:THR 18 CA 289 y', -0.9417318539428875, 208)
# ('aligned ATOM:THR 18 O 300 y', -0.9391031141148112, 214)
# ('aligned ATOM:THR 18 N 287 y', -0.935175532868319, 205)
# ('aligned ATOM:HIS 17 C 285 y', -0.9241606828025855, 199)
# ('aligned ATOM:GLN 19 N 301 y', -0.922247063849128, 217)
# ('aligned ATOM:HIS 17 O 286 y', -0.9160225884325034, 202)
# ('aligned ATOM:GLN 19 CA 303 y', -0.9088923362648155, 220)
# ('aligned ATOM:HIS 17 CA 272 y', -0.8955020828148603, 196)
# ('aligned ATOM:THR 9 N 148 y', -0.8856512477719087, 97)
# ('aligned ATOM:THR 9 CA 150 y', -0.8790108569919153, 100)
# ('aligned ATOM:PHE 31 O 502 y', -0.8724624308673099, 370)
# ('aligned ATOM:THR 18 CA 289 z', 0.8674159106956261, 209)
# ('aligned ATOM:HIS 17 N 270 y', -0.8637273671999995, 193)
# ('aligned ATOM:THR 18 C 299 z', 0.8627575274169571, 212)
# ...

# %%
print_corr(pca, yrl_10_gro_cc, ic=2)
# Out:
# Feature Label    Correlation   Feature index
# ('aligned ATOM:CYM 226 CA 3550 x', 0.7516265423555023, 2703)
# ('aligned ATOM:CYM 226 C 3556 x', 0.7464678090694818, 2706)
# ('aligned ATOM:CYM 226 O 3557 x', 0.7449523355553683, 2709)
# ('aligned ATOM:CYM 226 N 3548 x', 0.7407648101471042, 2700)
# ('aligned ATOM:THR 225 O 3547 x', 0.734220143578837, 2697)
# ('aligned ATOM:THR 225 C 3546 x', 0.7282296983485154, 2694)
# ('aligned ATOM:GLY 227 N 3558 x', 0.7214698769902118, 2712)
# ('aligned ATOM:CYM 224 O 3533 x', 0.7155409803575615, 2685)
# ('aligned ATOM:CYM 224 C 3532 x', 0.7000555924914883, 2682)
# ('aligned ATOM:GLY 227 CA 3560 x', 0.6996099549722944, 2715)
# ('aligned ATOM:THR 191 N 3013 x', 0.6922996546268848, 2280)
# ('aligned ATOM:THR 191 CA 3015 x', 0.6886965163139975, 2283)
# ('aligned ATOM:CYM 224 CA 3526 x', 0.6883777503862912, 2679)
# ('aligned ATOM:CYM 189 O 2990 x', 0.6874759580429257, 2265)
# ('aligned ATOM:THR 191 C 3025 x', 0.6873152568528046, 2286)
# ...

# %%
pca_yrl_10 = coor.pca(data=yrl_10_cc)
pca_yrl_10_data = pca_yrl_10.transform([yrl_10_cc, yrl_50_cc, yrl_100_cc])

# %%
fig, ax = plt.subplots(1,3, sharex=True, sharey=True, figsize=[19.2, 4.8])
for i,j in enumerate(ax.ravel()):
    pyemma_plots.plot_density(pca_yrl_10_data[i][:,0], pca_yrl_10_data[i][:,1], logscale=True, ax=j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_28721/3491409440.py in <module>
# ----> 1 fig, ax = plt.subplots(1,3, sharex=True, sharey=True, figsize=[19.2, 4.8])
#       2 for i,j in enumerate(ax.ravel()):
#       3     pyemma_plots.plot_density(pca_yrl_10_data[i][:,0], pca_yrl_10_data[i][:,1], logscale=True, ax=j)
#
# NameError: name 'plt' is not defined

# %%
fig, ax, m = pyemma_plots.plot_density(pca_data[1][:,0], pca_data[1][:,1], logscale=True, cbar=True)
fig.colorbar(m['mappable'], ax=ax)

#from matplotlib.ticker import LogLocator
#lomag = m['cbar'].set_ticks(LogLocator(numticks=4))
#m['cbar'].set_ticks(lomag)

# %%
m.keys()
# Out:
# dict_keys(['mappable', 'cbar'])

# %%
m['cbar'].set_label
# Out:
# <bound method Colorbar.update_ticks of <matplotlib.colorbar.Colorbar object at 0x7fb59f686340>>

# %%
crystal = md.load('7OFS/true_7ofs.gro')

# %%
lig = crystal.top.select('resname == yrl')

# %%
binding_site_neibors = md.compute_neighbors(crystal, 0.9, lig, crystal.top.select('name == CA or name == CB'))
# Out:
# /tmp/ipykernel_9701/2509717069.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   binding_site_neibors = md.compute_neighbors(crystal, 0.9, lig, crystal.top.select('name == CA or name == CB'))

# %%
binding_site_neibors[0].shape
# Out:
# (73,)

# %%
yrl_10_gro_bs = coor.featurizer('7OFS/10_milli_molar/analysis/frame0_nw.gro')
yrl_10_gro_bs.add_distances(binding_site_neibors[0])
yrl_10_bs =coor.load('7OFS/10_milli_molar/analysis/plpro_yrl_10_whole_wrap.trr', features=yrl_10_gro_bs)

yrl_50_gro_bs = coor.featurizer('7OFS/50_milli_molar/analysis/frame0_nw.gro')
yrl_50_gro_bs.add_distances(binding_site_neibors[0])
yrl_50_bs = coor.load('7OFS/50_milli_molar/analysis/plpro_yrl_50_whole_wrap.trr', features=yrl_50_gro_bs)

yrl_100_gro_bs = coor.featurizer('7OFS/100_milli_molar/analysis/frame0_nw.gro')
yrl_100_gro_bs.add_distances(binding_site_neibors[0])
yrl_100_bs = coor.load('7OFS/100_milli_molar/analysis/plpro_yrl_100_whole_wrap.trr', features=yrl_100_gro_bs)
# Out:
# 10-02-22 16:41:35 pyemma.coordinates.data.featurization.featurizer.MDFeaturizer[32] WARNING  The 1D arrays input for add_distances() have been sorted, and index duplicates have been eliminated.
# Check the output of describe() to see the actual order of the features
# 10-02-22 16:42:28 pyemma.coordinates.data.featurization.featurizer.MDFeaturizer[34] WARNING  The 1D arrays input for add_distances() have been sorted, and index duplicates have been eliminated.
# Check the output of describe() to see the actual order of the features
# 10-02-22 16:43:21 pyemma.coordinates.data.featurization.featurizer.MDFeaturizer[36] WARNING  The 1D arrays input for add_distances() have been sorted, and index duplicates have been eliminated.
# Check the output of describe() to see the actual order of the features

# %%
hba_10_gro_bs = coor.featurizer('7oft/10_mm/analysis/frame0_nw.gro')
hba_10_gro_bs.add_distances(binding_site_neibors[0])
hba_10_bs =coor.load('7oft/10_mm/analysis/7oft_10mm_whole_wrap.trr', features=hba_10_gro_bs)

hba_50_gro_bs = coor.featurizer('7oft/50_mm/analysis/frame0_nw.gro')
hba_50_gro_bs.add_distances(binding_site_neibors[0])
hba_50_bs = coor.load('7oft/50_mm/analysis/7oft_50mm_whole_wrap.trr', features=hba_50_gro_bs)

hba_100_gro_bs = coor.featurizer('7oft/100_mm/analysis/frame0_nw.gro')
hba_100_gro_bs.add_distances(binding_site_neibors[0])
hba_100_bs = coor.load('7oft/100_mm/analysis/7oft_100mm_whole_wrap.trr', features=hba_100_gro_bs)
# Out:
# 10-02-22 16:48:17 pyemma.coordinates.data.featurization.featurizer.MDFeaturizer[38] WARNING  The 1D arrays input for add_distances() have been sorted, and index duplicates have been eliminated.
# Check the output of describe() to see the actual order of the features
# 10-02-22 16:48:50 pyemma.coordinates.data.featurization.featurizer.MDFeaturizer[40] WARNING  The 1D arrays input for add_distances() have been sorted, and index duplicates have been eliminated.
# Check the output of describe() to see the actual order of the features
# 10-02-22 16:49:21 pyemma.coordinates.data.featurization.featurizer.MDFeaturizer[42] WARNING  The 1D arrays input for add_distances() have been sorted, and index duplicates have been eliminated.
# Check the output of describe() to see the actual order of the features

# %%
he9_10_gro_bs = coor.featurizer('7ofu/10_mm/analysis/frame0_nw.gro')
he9_10_gro_bs.add_distances(binding_site_neibors[0])
he9_10_bs =coor.load('7ofu/10_mm/analysis/7ofu_10mm_whole_wrap.trr', features=he9_10_gro_bs)

he9_50_gro_bs = coor.featurizer('7ofu/50_mm/analysis/frame0_nw.gro')
he9_50_gro_bs.add_distances(binding_site_neibors[0])
he9_50_bs = coor.load('7ofu/50_mm/analysis/7ofu_50mm_whole_wrap.trr', features=he9_50_gro_bs)

he9_100_gro_bs = coor.featurizer('7ofu/100_mm/analysis/frame0_nw.gro')
he9_100_gro_bs.add_distances(binding_site_neibors[0])
he9_100_bs = coor.load('7ofu/100_mm/analysis/7ofu_100mm_whole_wrap.trr', features=he9_100_gro_bs)
# Out:
# 10-02-22 16:52:09 pyemma.coordinates.data.featurization.featurizer.MDFeaturizer[44] WARNING  The 1D arrays input for add_distances() have been sorted, and index duplicates have been eliminated.
# Check the output of describe() to see the actual order of the features
# 10-02-22 16:52:49 pyemma.coordinates.data.featurization.featurizer.MDFeaturizer[46] WARNING  The 1D arrays input for add_distances() have been sorted, and index duplicates have been eliminated.
# Check the output of describe() to see the actual order of the features
# 10-02-22 16:53:28 pyemma.coordinates.data.featurization.featurizer.MDFeaturizer[48] WARNING  The 1D arrays input for add_distances() have been sorted, and index duplicates have been eliminated.
# Check the output of describe() to see the actual order of the features

# %%
pca_bs = coor.pca(data=[yrl_10_bs, yrl_50_bs, yrl_100_bs, hba_10_bs, hba_50_bs, hba_100_bs, he9_10_bs, he9_50_bs, he9_100_bs])
# Out:
# calc mean+cov:   0%|                                     | 0/18 [00:00<?, ?it/s]

# %%
pca_bs_data = pca_bs.get_output()
pca_bs.write_to_hdf5('pca_data_all9_binding_site.h5')
# Out:
# ...
# writing output:   0%|                                    | 0/18 [00:00<?, ?it/s]
# /home/jasonpattis/anaconda3/lib/python3.8/site-packages/pyemma/coordinates/data/_base/datasource.py:490: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   with h5py.File(filename) as f, it, pg.context():

# %%
pca_bs.cumvar[:10]
# Out:
# array([0.41071304, 0.60177087, 0.68835335, 0.73938401, 0.77613126,
#        0.80293748, 0.82574419, 0.84565286, 0.86054642, 0.87361486])

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    pyemma_plots.plot_density(pca_bs_data[i][:,0], pca_bs_data[i][:,1], logscale=True, ax=j)
    
ax[2][0].set_xlabel('PC 1', fontsize=16)
ax[2][1].set_xlabel('PC 1', fontsize=16)
ax[2][2].set_xlabel('PC 1', fontsize=16)

ax[0][0].set_ylabel('PC 2', fontsize=16)
ax[1][0].set_ylabel('PC 2', fontsize=16)
ax[2][0].set_ylabel('PC 2', fontsize=16)

ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    pyemma_plots.plot_density(pca_bs_data[i][:,0], pca_bs_data[i][:,2], logscale=True, ax=j)
    
ax[2][0].set_xlabel('PC 1', fontsize=16)
ax[2][1].set_xlabel('PC 1', fontsize=16)
ax[2][2].set_xlabel('PC 1', fontsize=16)

ax[0][0].set_ylabel('PC 3', fontsize=16)
ax[1][0].set_ylabel('PC 3', fontsize=16)
ax[2][0].set_ylabel('PC 3', fontsize=16)

ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
print_corr(pca_bs, yrl_10_gro_bs, ic=0)
# Out:
# Feature Label    Correlation   Feature index
# ('DIST: PRO 59 CA 923 - PRO 77 CA 1207', -0.9446383984295535, 1479)
# ('DIST: VAL 11 CB 180 - ASP 76 CB 1195', -0.9422863324643042, 395)
# ('DIST: VAL 11 CA 178 - ASP 76 CB 1195', -0.9420178729385725, 328)
# ('DIST: VAL 11 CB 180 - ASP 76 CA 1193', -0.9408589522721721, 394)
# ('DIST: VAL 11 CA 178 - THR 74 CA 1165', -0.9407107420468085, 323)
# ('DIST: THR 10 CA 164 - THR 74 CA 1165', -0.939469445932564, 186)
# ('DIST: VAL 11 CB 180 - THR 74 CA 1165', -0.9372982987512433, 390)
# ('DIST: THR 10 CB 166 - THR 74 CA 1165', -0.9311020539533185, 255)
# ('DIST: VAL 11 CA 178 - ASP 76 CA 1193', -0.928396571801479, 327)
# ('DIST: PRO 59 CB 925 - PRO 77 CA 1207', -0.9259592376482418, 1526)
# ('DIST: PRO 59 CA 923 - ASP 76 CB 1195', -0.918980787079875, 1478)
# ('DIST: THR 9 CA 150 - GLU 67 CA 1046', -0.9186538328690926, 32)
# ('DIST: THR 9 CA 150 - GLU 67 CB 1048', -0.9174913004089712, 33)
# ...

# %%
print_corr(pca_bs, yrl_10_gro_bs, ic=1)
# Out:
# Feature Label    Correlation   Feature index
# ('DIST: PRO 33 CA 514 - THR 75 CB 1181', -0.9620288137453776, 713)
# ('DIST: THR 34 CA 526 - THR 75 CB 1181', -0.9586856039079388, 834)
# ('DIST: THR 34 CA 526 - THR 75 CA 1179', -0.9553750707658326, 833)
# ('DIST: PRO 33 CB 516 - THR 75 CB 1181', -0.9514951255674671, 774)
# ('DIST: PRO 33 CA 514 - THR 75 CA 1179', -0.9494337000197575, 712)
# ('DIST: THR 34 CB 528 - THR 75 CB 1181', -0.9470489770114123, 893)
# ('DIST: TYR 35 CA 540 - THR 75 CB 1181', -0.9434354109478775, 951)
# ('DIST: TYR 35 CA 540 - THR 75 CA 1179', -0.9428021940829888, 950)
# ('DIST: THR 34 CB 528 - THR 75 CA 1179', -0.9405157432469676, 892)
# ('DIST: PRO 33 CB 516 - THR 75 CA 1179', -0.935201835388249, 773)
# ('DIST: TYR 35 CB 542 - THR 75 CB 1181', -0.9280112974670707, 1008)
# ('DIST: LEU 58 CB 904 - THR 75 CB 1181', -0.9268184126274825, 1428)
# ('DIST: TYR 35 CB 542 - THR 75 CA 1179', -0.9262852066454252, 1007)
# ...

# %%
print_corr(pca_bs, yrl_10_gro_bs, ic=2)
# Out:
# Feature Label    Correlation   Feature index
# ('DIST: PHE 55 CB 847 - SER 78 CB 1221', -0.8440423754937496, 1125)
# ('DIST: PHE 55 CA 845 - SER 78 CB 1221', -0.8351320530936337, 1070)
# ('DIST: PHE 55 CB 847 - SER 78 CA 1219', -0.819998785651854, 1124)
# ('DIST: TYR 35 CA 540 - SER 78 CB 1221', -0.8143824471324856, 957)
# ('DIST: PHE 55 CA 845 - SER 78 CA 1219', -0.8108566222352126, 1069)
# ('DIST: TYR 35 CB 542 - SER 78 CB 1221', -0.8090107174847353, 1014)
# ('DIST: THR 34 CA 526 - SER 78 CB 1221', -0.8055916133966494, 840)
# ('DIST: PRO 33 CA 514 - SER 78 CB 1221', -0.7960533646506777, 719)
# ('DIST: PHE 55 CB 847 - GLY 81 CA 1269', -0.7954246840710568, 1130)
# ('DIST: PHE 55 CA 845 - GLY 81 CA 1269', -0.7936381236271238, 1075)
# ('DIST: THR 34 CB 528 - SER 78 CB 1221', -0.7922476830950824, 899)
# ('DIST: TYR 35 CA 540 - GLY 81 CA 1269', -0.7912181658353028, 962)
# ('DIST: PRO 33 CB 516 - SER 78 CB 1221', -0.7910271980982594, 780)
# ...

# %%
import os
import shutil

def check_iter_of_sequences(sequences, allow_trajectory=False, ndim=2,
                            max_iter=None):
    """Check that ``sequences`` is a iterable of trajectory-like sequences,
    suitable as input to ``fit()`` for estimators following the MSMBuilder
    API.
    Parameters
    ----------
    sequences : object
        The object to check
    allow_trajectory : bool
        Are ``md.Trajectory``s allowed?
    ndim : int
        The expected dimensionality of the sequences
    max_iter : int, optional
        Only check at maximum the first ``max_iter`` entries in ``sequences``.
    """
    value = True
    for i, X in enumerate(sequences):
        if not isinstance(X, np.ndarray):
            if (not allow_trajectory) and isinstance(X, md.Trajectory):
                value = False
                break
        if not isinstance(X, md.Trajectory) and X.ndim != ndim:
            value = False
            break
        if max_iter is not None and i >= max_iter:
            break

    if not value:
        raise ValueError('sequences must be a list of sequences')

from scipy.spatial import KDTree as sp_KDTree

class KDTree(object):
    """kd-tree for quick nearest-neighbor lookup
    This class provides an index into a set of k-dimensional points which
    can be used to rapidly look up the nearest neighbors of any point.
    This class wraps sklearn's implementation by taking a list of arrays
    and returning indices of the form (traj_i, frame_i).
    Parameters
    ----------
    sequences : list of (N,K) array_like
        Each array contains data points to be indexed. This array is not
        copied, and so modifying this data will result in bogus results.
    leafsize : int, optional
        The number of points at which the algorithm switches over to
        brute-force. Has to be positive.
    Raises
    ------
    RuntimeError
        The maximum recursion limit can be exceeded for large data
        sets.  If this happens, either increase the value for the `leafsize`
        parameter or increase the recursion limit by::
            >>> import sys
            >>> sys.setrecursionlimit(10000)
    Notes
    -----
    The algorithm used is described in Maneewongvatana and Mount 1999.
    The general idea is that the kd-tree is a binary tree, each of whose
    nodes represents an axis-aligned hyperrectangle. Each node specifies
    an axis and splits the set of points based on whether their coordinate
    along that axis is greater than or less than a particular value.
    During construction, the axis and splitting point are chosen by the
    "sliding midpoint" rule, which ensures that the cells do not all
    become long and thin.
    The tree can be queried for the r closest neighbors of any given point
    (optionally returning only those within some maximum distance of the
    point). It can also be queried, with a substantial gain in efficiency,
    for the r approximate closest neighbors.
    For large dimensions (20 is already large) do not expect this to run
    significantly faster than brute force. High-dimensional nearest-neighbor
    queries are a substantial open problem in computer science.
    The tree also supports all-neighbors queries, both with arrays of points
    and with other kd-trees. These do use a reasonably efficient algorithm,
    but the kd-tree is not necessarily the best data structure for this
    sort of calculation.
    """

    _allow_trajectory = False

    def __init__(self, sequences, leafsize=10):
        check_iter_of_sequences(sequences,
                                allow_trajectory=self._allow_trajectory)
        self._kdtree = sp_KDTree(self._concat(sequences), leafsize=leafsize)

    def query(self, x, k=1, p=2, distance_upper_bound=np.inf):
        """Query the kd-tree for nearest neighbors
        Parameters
        ----------
        x : array_like, last dimension self.m
            An array of points to query.
        k : int, optional
            The number of nearest neighbors to return.
        eps : nonnegative float, optional
            Return approximate nearest neighbors; the kth returned value
            is guaranteed to be no further than (1+eps) times the
            distance to the real kth nearest neighbor.
        p : float, 1<=p<=infinity, optional
            Which Minkowski p-norm to use.
            1 is the sum-of-absolute-values "Manhattan" distance
            2 is the usual Euclidean distance
            infinity is the maximum-coordinate-difference distance
        distance_upper_bound : nonnegative float, optional
            Return only neighbors within this distance. This is used to prune
            tree searches, so if you are doing a series of nearest-neighbor
            queries, it may help to supply the distance to the nearest neighbor
            of the most recent point.
        Returns
        -------
        d : float or array of floats
            The distances to the nearest neighbors.
            If x has shape tuple+(self.m,), then d has shape tuple if
            k is one, or tuple+(k,) if k is larger than one. Missing
            neighbors (e.g. when k > n or distance_upper_bound is
            given) are indicated with infinite distances.  If k is None,
            then d is an object array of shape tuple, containing lists
            of distances. In either case the hits are sorted by distance
            (nearest first).
        i : tuple(int, int) or array of tuple(int, int)
            The locations of the neighbors in self.data. Locations are
            given by tuples of (traj_i, frame_i)
        Examples
        --------
        >>> from msmbuilder.utils import KDTree
        >>> X1 = 0.3 * np.random.RandomState(0).randn(500, 2)
        >>> X2 = 0.3 * np.random.RandomState(1).randn(1000, 2) + 10
        >>> tree = KDTree([X1, X2])
        >>> pts = np.array([[0, 0], [10, 10]])
        >>> tree.query(pts)
        (array([ 0.0034,  0.0102]), array([[  0, 410], [  1, 670]]))
        >>> tree.query(pts[0])
        (0.0034, array([  0, 410]))
        """
        cdists, cinds = self._kdtree.query(x, k, p, distance_upper_bound)
        return cdists, self._split_indices(cinds)

    # concat and split code lovingly copied from MultiSequenceClusterMixin
    def _concat(self, sequences):
        self.__lengths = [len(s) for s in sequences]
        if len(sequences) > 0 and isinstance(sequences[0], np.ndarray):
            concat = np.ascontiguousarray(np.concatenate(sequences))
        else:
            raise TypeError('sequences must be a list of numpy arrays')

        assert sum(self.__lengths) == len(concat)
        return concat

    def _split(self, concat):
        return [concat[cl - l: cl] for (cl, l) in
                zip(np.cumsum(self.__lengths), self.__lengths)]

    def _split_indices(self, concat_inds):
        """Take indices in 'concatenated space' and return as pairs
        of (traj_i, frame_i)
        """
        clengths = np.append([0], np.cumsum(self.__lengths))
        mapping = np.zeros((clengths[-1], 2), dtype=int)
        for traj_i, (start, end) in enumerate(zip(clengths[:-1], clengths[1:])):
            mapping[start:end, 0] = traj_i
            mapping[start:end, 1] = np.arange(end - start)
        return mapping[concat_inds]

# %%
kmeans = coor.cluster_kmeans(pca_bs_data, k=6, max_iter=100)
# Out:
# ...
# kmeans iterations:   0%|                                | 0/100 [00:00<?, ?it/s]

# %%
kmeans.clustercenters.shape
# Out:
# (6, 26)

# %%
tree = KDTree(pca_bs_data)

# %%
index_list = [0] * 6
for i in range(6):
    _, index_list[i] = tree.query(kmeans.clustercenters[i], k=1)

# %%
index_list
# Out:
# [array([    0, 20498]),
#  array([    4, 18098]),
#  array([    2, 25253]),
#  array([   5, 6165]),
#  array([    7, 23175]),
#  array([   3, 7538])]

# %%
pdb_list = ['7OFS/10_milli_molar/analysis/frame0_nw.gro', '7OFS/50_milli_molar/analysis/frame0_nw.gro', '7OFS/100_milli_molar/analysis/frame0_nw.gro',
           '7oft/10_mm/analysis/frame0_nw.gro', '7oft/50_mm/analysis/frame0_nw.gro', '7oft/100_mm/analysis/frame0_nw.gro', 
           '7ofu/10_mm/analysis/frame0_nw.gro', '7ofu/50_mm/analysis/frame0_nw.gro', '7ofu/100_mm/analysis/frame0_nw.gro']

# %%
traj_name_list = ['7OFS/10_milli_molar/analysis/plpro_yrl_10_whole_wrap.trr', '7OFS/50_milli_molar/analysis/plpro_yrl_50_whole_wrap.trr', '7OFS/100_milli_molar/analysis/plpro_yrl_100_whole_wrap.trr', 
                 '7oft/10_mm/analysis/7oft_10mm_whole_wrap.trr', '7oft/50_mm/analysis/7oft_50mm_whole_wrap.trr', '7oft/100_mm/analysis/7oft_100mm_whole_wrap.trr',
                 '7ofu/10_mm/analysis/7ofu_10mm_whole_wrap.trr', '7ofu/50_mm/analysis/7ofu_50mm_whole_wrap.trr', '7ofu/100_mm/analysis/7ofu_100mm_whole_wrap.trr']

# %%
new_pdb = md.load_frame(traj_name_list[index_list[i][0]], index=index_list[i][1], top=pdb_list[index_list[i][0]])
new_pdb.save_pdb(f'pca_cc2_PC1_min.pdb')

# %%
pca_data2 = coor.load('pca_data_all9_cc_try2.h5')
# Out:
# getting output of H5Reader:   0%|                                                                             …

# %%
traj_list = [yrl_10, yrl_50, yrl_100, hba_10, hba_50, hba_100, he9_10, he9_50, he9_100]

# %%
dist_84_38 = [md.compute_distances(i, np.array([yrl_10_gro.top.select('residue 84 and name CA'), yrl_10_gro.top.select('residue 38 and name CA') ]).T) for i in traj_list]

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, dist_84_38[i])
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('distance', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
dist_18_134 = [md.compute_distances(i, np.array([yrl_10_gro.top.select('residue 18 and name CA'), yrl_10_gro.top.select('residue 134 and name CA') ]).T) for i in traj_list]

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, dist_18_134[i])
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('distance', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
dist_59_77 = [md.compute_distances(i, np.array([yrl_10_gro.top.select('residue 59 and name CA'), yrl_10_gro.top.select('residue 77 and name CA') ]).T) for i in traj_list]

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, dist_59_77[i])
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('distance', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
dist_33_75 = [md.compute_distances(i, np.array([yrl_10_gro.top.select('residue 33 and name CA'), yrl_10_gro.top.select('residue 75 and name CA') ]).T) for i in traj_list]

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, dist_33_75[i])
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('distance', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
ang_88_81_38 = [md.compute_angles(i, np.array([yrl_10_gro.top.select('residue 88 and name CA'), yrl_10_gro.top.select('residue 81 and name CA'), yrl_10_gro.top.select('residue 38 and name CA')]).T) for i in traj_list]

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, ang_88_81_38[i])
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('angle', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
ang_134_84_8 = [md.compute_angles(i, np.array([yrl_10_gro.top.select('residue 134 and name CA'), yrl_10_gro.top.select('residue 84 and name CA'), yrl_10_gro.top.select('residue 8 and name CA')]).T) for i in traj_list]

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, ang_134_84_8[i])
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('angle (rad)', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)

fig.savefig('angle_134_84_8.png')

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, pca_data2[i][:,0])
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('PC 1', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, pca_data2[i][:,1])

for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('PC 2', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
ang_146_153_64 = [md.compute_angles(i, np.array([yrl_10_gro.top.select('residue 146 and name CA'), yrl_10_gro.top.select('residue 153 and name CA'), yrl_10_gro.top.select('residue 64 and name CA')]).T) for i in traj_list]

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, ang_146_153_64[i])
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('angle (rad)', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)

#fig.savefig('angle_146_153_64.png')
# Out:
# Text(0.5, 1.0, '100 mm')

# %%
ang_88_81_5 = [md.compute_angles(i, np.array([yrl_10_gro.top.select('residue 88 and name CA'), yrl_10_gro.top.select('residue 81 and name CA'), yrl_10_gro.top.select('residue 5 and name CA')]).T) for i in traj_list]

# %%
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
for i,j in enumerate(ax.ravel()):
    j.plot(time, ang_88_81_5[i])
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('angle (rad)', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)

fig.savefig('angle_88_81_5.png')

# %%
data_yrl = np.loadtxt('7OFS/md_pocket/s11/mdpout_descriptors.txt')
data_hba = np.loadtxt('7oft/md_pocket/try2/s11/mdpout_descriptors.txt')
data_he9 = np.loadtxt('7ofu/md_pocket/site_11/mdpout_descriptors.txt')

# %%
data_yrl.shape
# Out:
# (9087, 42)

# %%
data_hba.shape
# Out:
# (9003, 42)

# %%
data_he9.shape
# Out:
# (9003, 42)

# %%
time2 = np.arange(0,300.1, 0.1)
fig, ax = plt.subplots(3,3, sharex=True, sharey=True, figsize=[12.8, 9.6])
ax[0][0].plot(time2, data_yrl[:3001,1])
ax[0][1].plot(time2, data_yrl[3001:6002,1])
ax[0][2].plot(time2, data_yrl[6086:,1])

ax[1][0].plot(time2, data_hba[:3001,1])
ax[1][1].plot(time2, data_hba[3001:6002,1])
ax[1][2].plot(time2, data_hba[6002:,1])

ax[2][0].plot(time2, data_he9[:3001,1])
ax[2][1].plot(time2, data_he9[3001:6002,1])
ax[2][2].plot(time2, data_he9[6002:,1])

for i in range(3):
    ax[0][i].axhline(y=604, color='r', linestyle='--')

for i in range(3):
    ax[1][i].axhline(y=507, color='r', linestyle='--')

for i in range(3):
    ax[2][i].axhline(y=424, color='r', linestyle='--')   
    
for i in range(3):
    ax[2][i].set_xlabel('time (ns)', fontsize=16)
    
for i in range(3):
    ax[i][0].set_ylabel('Pocket Volume ($\AA^3$)', fontsize=16)
    
ax[0][0].set_title('10 mm', fontsize=20)
ax[0][1].set_title('50 mm', fontsize=20)
ax[0][2].set_title('100 mm', fontsize=20)
    
fig.savefig('pocket_volume_all9.png')
